# %%
import pandas as pd

df = pd.read_csv("../TPFinal/NintendoGames.csv",sep = ",")

# %%
df.head()
# Out:
#    meta_score                      title platform          date  user_score  \
# 0         NaN            Super Mario RPG   Switch  Nov 17, 2023         NaN
# 1         NaN        WarioWare: Move It!   Switch   Nov 3, 2023         NaN
# 2         NaN   Super Mario Bros. Wonder   Switch  Oct 20, 2023         NaN
# 3         NaN  Detective Pikachu Returns   Switch   Oct 6, 2023         NaN
# 4         NaN                   Fae Farm   Switch   Sep 8, 2023         NaN
#
#                                      link esrb_rating  \
# 0            /game/switch/super-mario-rpg           E
# 1         /game/switch/warioware-move-it!          RP
# 2    /game/switch/super-mario-bros-wonder           E
# 3  /game/switch/detective-pikachu-returns         NaN
# 4                   /game/switch/fae-farm        E10+
#
#                 developers                                     genres
# 0             ['Nintendo']         ['Role-Playing', 'Japanese-Style']
# ...

# %%
print(df.shape)
# Out:
# (1094, 9)

# %%
df.count()
# Out:
# meta_score      709
# title          1094
# platform       1094
# date           1094
# user_score      856
# link           1094
# esrb_rating     972
# developers     1091
# genres         1094
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 9 columns):
# meta_score     709 non-null float64
# title          1094 non-null object
# platform       1094 non-null object
# date           1094 non-null object
# user_score     856 non-null float64
# link           1094 non-null object
# esrb_rating    972 non-null object
# developers     1091 non-null object
# genres         1094 non-null object
# dtypes: float64(2), object(7)
# memory usage: 77.0+ KB

# %%
df.dtypes
# Out:
# meta_score     float64
# title           object
# platform        object
# date            object
# user_score     float64
# link            object
# esrb_rating     object
# developers      object
# genres          object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.columns)
# Out:
# Index(['meta_score', 'title', 'platform', 'date', 'user_score', 'link',
#        'esrb_rating', 'developers', 'genres'],
#       dtype='object')

# %%
#Listado de los mejores juegos según usuarios
df.nlargest(10,'user_score')
# Out:
#       meta_score                             title platform          date  \
# 612         62.0                     Metal Torrent       DS  May 24, 2010
# 802          NaN                     Super Metroid      WII  Aug 20, 2007
# 636         87.0        Pokemon SoulSilver Version       DS  Mar 14, 2010
# 690         91.0             Metroid Prime Trilogy      WII  Aug 24, 2009
# 1062        92.0                     Banjo-Kazooie      N64  May 31, 1998
# 203          NaN  Fire Emblem Warriors: Fates Pack      3DS  Dec 21, 2017
# 327         84.0            Xenoblade Chronicles X     WIIU   Dec 4, 2015
# 520         92.0              Xenoblade Chronicles      WII   Apr 6, 2012
# 613         97.0              Super Mario Galaxy 2      WII  May 23, 2010
# 635         87.0         Pokemon HeartGold Version       DS  Mar 14, 2010
#
#       user_score                                       link esrb_rating  \
# 612          9.6                     /game/ds/metal-torrent           E
# ...

# %%
#Listado de los mejores juegos según críticos
df.nlargest(10,'meta_score')
# Out:
#       meta_score                                      title platform  \
# 1060        99.0       The Legend of Zelda: Ocarina of Time      N64
# 214         97.0                        Super Mario Odyssey   Switch
# 266         97.0    The Legend of Zelda: Breath of the Wild   Switch
# 613         97.0                       Super Mario Galaxy 2      WII
# 783         97.0                         Super Mario Galaxy      WII
# 1017        97.0                              Metroid Prime       GC
# 1053        97.0                               Perfect Dark      N64
# 12          96.0  The Legend of Zelda: Tears of the Kingdom   Switch
# 265         96.0    The Legend of Zelda: Breath of the Wild     WIIU
# 866         96.0     The Legend of Zelda: Twilight Princess       GC
#
#               date  user_score  \
# 1060  Nov 23, 1998         9.1
# 214   Oct 27, 2017         8.9
# 266    Mar 3, 2017         8.7
# 613   May 23, 2010         9.1
# 783   Nov 12, 2007         9.1
# ...

# %%
#Desarrolladores mas populares con Nintendo
df['developers'].value_counts().head(10)
# Out:
# ['Nintendo']                     354
# ['Intelligent Systems']           95
# ['Game Freak']                    45
# ['HAL Labs']                      34
# ['Level 5']                       27
# ['Omega Force']                   16
# ['Monolith Soft']                 15
# ['Rare Ltd.']                     15
# ['Camelot Software Planning']     15
# ['Arika']                         11
# Name: developers, dtype: int64

# %%
#plataforma que mas juegos obtuvo con Nintendo
df['platform'].value_counts().head(10).plot(kind='bar')

# %%
df.describe().T
# Out:
#             count       mean        std   min   25%   50%   75%   max
# meta_score  709.0  76.083216  10.610735  37.0  69.0  77.0  83.0  99.0
# user_score  856.0   7.671612   1.031266   3.1   7.2   7.9   8.4   9.6
